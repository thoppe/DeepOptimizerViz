# %%
import tensorflow as tf
import pylab as plt
import numpy as np

# %% [markdown]
# ### Simple linear equation

# %%
x = tf.Variable(1.0)
f = 3*x - 2

# %%
loss = tf.reduce_sum(f**2)
opt = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train_op = opt.minimize(loss)

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

result = []
for n in range(30):
    _, x_val = sess.run([train_op, x])
    result.append(x_val)


plt.plot(result)

yc = np.ones(len(result))
plt.plot(yc*(2.0/3), 'r--')
plt.figure()

# %% [markdown]
# ### Quadratic equation

# %%
def complex_square(a,b):
    return

# %%
x = tf.Variable([-1.0, 3.3], dtype=tf.complex128)
f0 = x[0]**2 - 2*x[0] - 1
#f1 = x[1]**2 - 2*x[1] - 1
#f1 /= (x[1] - x[0])

# %%
loss = tf.abs(f0)
#loss = tf.reduce_sum(f0**2 + f1**2)
opt = tf.train.GradientDescentOptimizer(learning_rate=0.001)
train_op = opt.minimize(loss)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-043491fb2949> in <module>()
#       2 #loss = tf.reduce_sum(f0**2 + f1**2)
#       3 opt = tf.train.GradientDescentOptimizer(learning_rate=0.001)
# ----> 4 train_op = opt.minimize(loss)
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in minimize(self, loss, global_step, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, name, grad_loss)
#     398         aggregation_method=aggregation_method,
#     399         colocate_gradients_with_ops=colocate_gradients_with_ops,
# --> 400         grad_loss=grad_loss)
#     401
#     402     vars_with_grad = [v for g, v in grads_and_vars if g is not None]
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in compute_gradients(self, loss, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, grad_loss)
#     517     grads_and_vars = list(zip(grads, var_list))
#     518     self._assert_valid_dtypes(
# --> 519         [v for g, v in grads_and_vars
#     520          if g is not None and v.dtype != dtypes.resource])
#     521     return grads_and_vars
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in _assert_valid_dtypes(self, tensors)
#     874         raise ValueError(
#     875             "Invalid type %r for %s, expected: %s." % (
# --> 876                 dtype, t.name, [v for v in valid_dtypes]))
#     877
#     878   # --------------
#
# ValueError: Invalid type tf.complex128 for Variable_5:0, expected: [tf.float32, tf.float64, tf.float16, tf.bfloat16].

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

result = []
for n in range(500):
    _, x_val = sess.run([train_op, x])
    result.append(x_val)
    
result = np.array(result)
print(result)


plt.plot(result.real)

yc = np.ones(len(result))
plt.plot(yc*(1+np.sqrt(2.0)), 'r--')
plt.plot(yc*(1-np.sqrt(2.0)), 'r--')

plt.figure()
# Out:
# [[-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]
#  [-1. +0.j  3.3+0.j]]
